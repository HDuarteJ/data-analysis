# %% [markdown]
# ### Retrieving financial data in python using Yahoo Finance

# %%
pip install yfinance

# %%
import pandas as pd
import requests
import yfinance as yf

# %%
import yfinance as yf
dat = yf.Ticker("BBAS3.SA")

# %%
df = dat.history(period='1mo')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2025-07-21 00:00:00-03:00  20.360001  20.410000  19.860001  19.860001
# 2025-07-22 00:00:00-03:00  19.990000  20.180000  19.870001  19.889999
# 2025-07-23 00:00:00-03:00  19.950001  20.420000  19.870001  20.209999
# 2025-07-24 00:00:00-03:00  20.190001  20.230000  19.900000  20.070000
# 2025-07-25 00:00:00-03:00  20.190001  20.469999  20.129999  20.240000
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-07-21 00:00:00-03:00  42352600        0.0           0.0
# 2025-07-22 00:00:00-03:00  24707100        0.0           0.0
# 2025-07-23 00:00:00-03:00  35932600        0.0           0.0
# 2025-07-24 00:00:00-03:00  44775000        0.0           0.0
# 2025-07-25 00:00:00-03:00  38899700        0.0           0.0
